# %% [markdown]
# ## Register the Vitessce notebook kernel
#
# After creating the Vitessce environment, VS Code or Jupyter may not immediately show it in the kernel picker. If you cannot select `targeted-transcriptomics-training-vitessce`, run the following once from a terminal.
#
# On macOS, Linux, or WSL, from the repository root:
#
# ```bash
# cd vitessce
# source .venv/bin/activate
# python -m ipykernel install --user \
#   --name targeted-transcriptomics-training-vitessce \
#   --display-name targeted-transcriptomics-training-vitessce
# ```
#
# On Windows PowerShell, from the repository root:
#
# ```powershell
# cd vitessce
# . .\.venv\Scripts\Activate.ps1
# python -m ipykernel install --user `
#   --name targeted-transcriptomics-training-vitessce `
#   --display-name targeted-transcriptomics-training-vitessce
# ```
#
# Then reopen the notebook or refresh the kernel picker and select `targeted-transcriptomics-training-vitessce`.

# %% [markdown]
# ## MACSima example

# %%
import sys
import tempfile
from pathlib import Path

import harpy as hp
import harpy_vitessce as hpv
from IPython.display import HTML, display

if sys.platform == "win32":
    # Force short paths to avoid running into Windows limitation with path > 260 characters.
    temp_dir = "c:\\tmp"
    course_data_cache_path = "c:\\hp_cache"
else:
    temp_dir = None  # use OS default
    course_data_cache_path = None  # use OS default

output_dir = Path(tempfile.TemporaryDirectory(dir=temp_dir, prefix="macsima_").name)

sdata = hp.datasets.macsima_colorectal_carcinoma_course(
    checkpoint="checkpoint_2",
    path=course_data_cache_path,
)
# Out:
# WARNING  Module 'bioio' is not installed. Install it with `pip install bioio` to use `harpy.io.macsima`.
# WARNING  Module 'bioio-ome-tiff' is not installed. Install it with `pip install bioio-ome-tiff` to use
#          `harpy.io.macsima`.
# no parent found for <ome_zarr.reader.Label object at 0x1211226c0>: None
# no parent found for <ome_zarr.reader.Label object at 0x121122a50>: None
# no parent found for <ome_zarr.reader.Label object at 0x12116a030>: None
# no parent found for <ome_zarr.reader.Label object at 0x1211806e0>: None

# %%
from spatialdata import read_zarr

sdata.write(output_dir / "sdata.zarr", overwrite=True)
sdata = read_zarr(sdata.path)
# Out:
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# no parent found for <ome_zarr.reader.Label object at 0x12222f080>: None
# no parent found for <ome_zarr.reader.Label object at 0x121a30320>: None
# no parent found for <ome_zarr.reader.Label object at 0x1219d5040>: None
# no parent found for <ome_zarr.reader.Label object at 0x121cb3740>: None

# %% [markdown]
# Lets start simple:

# %%
from pathlib import Path

sdata_for_vitessce = sdata.path
vitessce_base_dir = None

p = Path(sdata.path)
sdata_for_vitessce = p.relative_to(Path(p.anchor)).as_posix()
vitessce_base_dir = p.anchor

# %%
vc = hpv.proteomics_from_spatialdata(
    sdata_for_vitessce,
    base_dir=vitessce_base_dir,
    image_name="REAscreen_IO_CRC",
    channels=["DAPI"],
    palette=["#00C2FF"],
    to_coordinate_system="global_1_micron",
)

url = vc.web_app()
display(HTML(f'<a href="{url}" target="_blank">Open in Vitessce</a>'))
# Out:
# 2026-06-18 11:47:42.937 | WARNING  | harpy_vitessce.vitessce_config._utils:_validate_camera:28 - zoom was provided without center. Vitessce ignores zoom unless center is also set.
22%3A+%5B%22init_A_image_0%22%5D%7D%2C+%22x%22%3A+8%2C+%22y%22%3A+0%2C+%22w%22%3A+4%2C+%22h%22%3A+4%2C+%22props%22%3A+%7B%22disableChannelsIfRgbDetected%22%3A+false%7D%7D%2C+%7B%22component%22%3A+%22obsSets%22%2C+%22coordinationScopes%22%3A+%7B%22d ...

# %%
vc = hpv.proteomics_from_spatialdata(
    sdata_for_vitessce,
    base_dir=vitessce_base_dir,
    image_name="REAscreen_IO_CRC",
    channels=["DAPI", "Bcl 2"],
    zoom=0.3,
    center=(255, 255),
    palette=["#00C2FF", "#FF1744"],
    channel_windows=[(0, 45000), (141, 231)],
    to_coordinate_system="global_1_micron",
)

url = vc.web_app()
display(HTML(f'<a href="{url}" target="_blank">Open in Vitessce</a>'))

# %% [markdown]
# Now add a segmentation mask:

# %%
vc = hpv.proteomics_from_spatialdata(
    sdata_for_vitessce,
    base_dir=vitessce_base_dir,
    image_name="REAscreen_IO_CRC",
    labels_name="labels_cells_instanseg",
    channels=["DAPI"],
    to_coordinate_system="global_1_micron",
)

url = vc.web_app()
display(HTML(f'<a href="{url}" target="_blank">Open in Vitessce</a>'))

# %%
vc = hpv.proteomics_from_spatialdata(
    sdata_for_vitessce,
    base_dir=vitessce_base_dir,
    image_name="REAscreen_IO_CRC",
    labels_name="labels_cells_instanseg",
    segmentation_filled=False,
    segmentation_stroke_width=0.01,
    segmentation_color="#00E5A8",  # be carefull -> when setting segmentation color, and also a cluster key, the segmentation color will overwrite the cluster key color
    channels=["DAPI"],
    to_coordinate_system="global_1_micron",
)

url = vc.web_app()
display(HTML(f'<a href="{url}" target="_blank">Open in Vitessce</a>'))

# %% [markdown]
# Add a cluster key:

# %%
sdata["table_cells_z_scored_filterd"].obs.head()

# %%
vc = hpv.proteomics_from_spatialdata(
    sdata_for_vitessce,
    base_dir=vitessce_base_dir,
    image_name="REAscreen_IO_CRC",
    labels_name="labels_cells_instanseg",
    table_name="table_cells_z_scored_filterd",
    channels=["DAPI"],
    cluster_key="leiden",
    embedding_key="X_umap",
    to_coordinate_system="global_1_micron",
)

url = vc.web_app()
display(HTML(f'<a href="{url}" target="_blank">Open in Vitessce</a>'))

# %% [markdown]
# Visualize the heatmap and a marker list

# %%
vc = hpv.proteomics_from_spatialdata(
    sdata_for_vitessce,
    base_dir=vitessce_base_dir,
    image_name="REAscreen_IO_CRC",
    labels_name="labels_cells_instanseg",
    table_name="table_cells_z_scored_filterd",
    channels=["DAPI"],
    cluster_key="leiden",
    embedding_key="X_umap",
    visualize_feature_matrix=True,
    visualize_heatmap=True,
    to_coordinate_system="global_1",
)

url = vc.web_app()
display(HTML(f'<a href="{url}" target="_blank">Open in Vitessce</a>'))

# or here:
# vc.widget()
# Out:
# 2026-06-18 11:48:28.751 | WARNING  | harpy_vitessce.vitessce_config._utils:_validate_camera:28 - zoom was provided without center. Vitessce ignores zoom unless center is also set.
# 2026-06-18 11:48:28.754 | INFO     | harpy_vitessce.vitessce_config._image:build_image_layer_config:154 - No palette provided and one channel selected; rendering channel in white (#FFFFFF).
# <a href="http://vitessce.io/#?theme=light&url=data:,%7B%22version%22%3A+%221.0.18%22%2C+%22name%22%3A+%22Proteomics%22%2C+%22description%22%3A+%22Proteomics%22%2C+%22datasets%22%3A+%5B%7B%22uid%22%3A+%22A%22%2C+%22name%22%3A+%22Proteomics%22%2C+%22files%22%3A+%5B%7B%22fileType%22%3A+%22spatialdata.zarr%22%2C+%22url%22%3A+%22http%3A%2F%2Flocalhost%3A8002%2Fvar%2Ffolders%2Fsz%2Ft3tgg4fs4tz9btm0fbqg_tzc0000gn%2FT%2Fmacsima_a2408e67%2Fsdata.zarr%22%2C+%22options%22%3A+%7B%22obsFeatureMatrix%22%3A+%7B%22path%22%3A+%22tables%2Ftable_cells_z_scored_filterd%2FX%22%2C+%22region%22%3A+%22labels_cells_instanseg%22%7D%2C+%22obsSets%22
22init_A_image_0%22%3A+%7B%22imageLayer%22%3A+%7B%22fileUid%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%7D%2C+%22spatialLayerVisible%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%7D%2C+%22spatialLayerOpacity%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%7D%2C+%22imageChannel%22%3A+%7B%22init_A_image_0%22%3A+%5B%22init_A_image_0%22%5D%7D%2C+%22photometricInterpretation%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%7D%7D%2C+%22imageChannel%22%3A+%7B%22spatialTargetC%22%3A+ ...

# %% [markdown]
# ## Xenium example

# %%
sdata = hp.datasets.xenium_human_ovarian_cancer_course(
    checkpoint="checkpoint_2",
    path=course_data_cache_path,
)

output_dir = Path(tempfile.TemporaryDirectory(dir=temp_dir, prefix="macsima_").name)

sdata.write(output_dir / "sdata.zarr", overwrite=True)

sdata = read_zarr(sdata.path)
# Out:
# no parent found for <ome_zarr.reader.Label object at 0x126bd64e0>: None
# no parent found for <ome_zarr.reader.Label object at 0x126c5cbf0>: None
# no parent found for <ome_zarr.reader.Label object at 0x126c6fd40>: None
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/contextlib.py:137: UserWarning: zarr v3 autosharding will be the default in the next minor release.
#   return next(self.gen)
# no parent found for <ome_zarr.reader.Label object at 0x12226bec0>: None
# no parent found for <ome_zarr.reader.Label object at 0x12745e930>: None
# no parent found for <ome_zarr.reader.Label object at 0x12745e750>: None
# /Users/arne.defauw/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/functools.py:912: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
sdata_for_vitessce = sdata.path
vitessce_base_dir = None

p = Path(sdata.path)
sdata_for_vitessce = p.relative_to(Path(p.anchor)).as_posix()
vitessce_base_dir = p.anchor

# %%
vc = hpv.imgbased_transcriptomics_from_spatialdata(
    sdata_for_vitessce,
    base_dir=vitessce_base_dir,
    image_name="clahe",
    channels=[0, 1, 2, 3],
    to_coordinate_system="global_micron",
)

url = vc.web_app()
display(HTML(f'<a href="{url}" target="_blank">Open in Vitessce</a>'))
# Out:
# 2026-06-18 11:49:40.438 | WARNING  | harpy_vitessce.vitessce_config._utils:_validate_camera:28 - zoom was provided without center. Vitessce ignores zoom unless center is also set.
# 2026-06-18 11:49:40.440 | INFO     | harpy_vitessce.vitessce_config._image:build_image_layer_config:158 - No palette provided and 4 channels selected; rendering with the default channel palette.
# <a href="http://vitessce.io/#?theme=light&url=data:,%7B%22version%22%3A+%221.0.18%22%2C+%22name%22%3A+%22Image-based+transcriptomics%22%2C+%22description%22%3A+%22Image-based+transcriptomics%22%2C+%22datasets%22%3A+%5B%7B%22uid%22%3A+%22A%22%2C+%22name%22%3A+%22Image-based+transcriptomics%22%2C+%22files%22%3A+%5B%7B%22fileType%22%3A+%22spatialdata.zarr%22%2C+%22url%22%3A+%22http%3A%2F%2Flocalhost%3A8003%2Fvar%2Ffolders%2Fsz%2Ft3tgg4fs4tz9btm0fbqg_tzc0000gn%2FT%2Fmacsima_1olhr4uw%2Fsdata.zarr%22%2C+%22options%22%3A+%7B%22image%22%3A+%7B%22path%22%3A+%22images%2Fclahe%22%2C+%22coordinateSystem%22%3A+%22global_micron%22%7D%7D%2C+%22coordinationValues%22%3A+%7B%22obsType%22%3A+%22cell%22%2C+%22fileUid%22%3A+%22sdata_f7634e29-21e8-4018-988e-cf508c5a36fa%22%7D%7D%5D%7D%5D%2C+%22coordinationSpace%22%3A+%7B%22dataset%22%3A+%7B%22A%22%3A+%22A%22%7D%2C+%22spatialZoom%22%3A+%7B%22A%22%3A+-4%7D%2C+%22spatialTargetX%22%3A+%7B%22A%22%3A+null%7D%2C+%22spatialTargetY%22%3A+%7B%22A%22%3A+null%7D%2C+%22imageLayer%22%3A+%7B%22init_A_image_0%22%3A+%22__dummy__%22%7D%2C+%22fileUid%22%3A+%7B%22init_A_image_0%22%3A+%22sdata_f7634e29-21e8-4018-988e-cf508c5a36fa%22%7D%2C+%22spatialLayerVisible%22%3A+%7B%22init_A_image_0%22%3A+true%7D%2C+%22spatialLayerOpacity%22%3A+%7B%22init_A_image_0%22%3A+1.0%7D%2C+%22imageChannel%22%3A+%7B%22init_A_image_0%22%3A+%22__dummy__%22%2C+%22init_A_image_1%22%3A+%22__dummy__%22%2C+%22init_A_image_2%22%3A+%22__dummy__%22%2C+%22init_A_image_3%22%3A+%22__dummy__%22%7D%2C+%22spatialTargetC%22%3A+%7B%22init_A_image_0%22%3A+0%2C+%22init_A_image_1%22%3A+1%2C+%22init_A_image_2%22%3A+2%2C+%22init_A_image_3%22%3A+3%7D%2C+%22spatialChannelColor%22%3A+%7B%22init_A_image_0%22%3A+%5B0%2C+255%2C+255%5D%2C+%22init_A_image_1%22%3A+%5B255%2C+0%2C+255%5D%2C+%22init_A_image_2%22%3A+%5B255%2C+165%2C+0%5D%2C+%22init_A_image_3%22%3A+%5B173%2C+255%2C+47%5D%7D%2C+%22spatialChannelVisible%22%3A+%7B%22init_A_image_0%22%3A+true%2C+%22init_A_image_1%22%3A+true%2C+%22init_A_image_2%22%3A+true%2C+%22init_A_image_3%22%3A+true%7D%2C+%22spatialChannelWindow%22%3A+%7B%22init_A_image_0%22%3A+null%2C+%22init_A_image_1%22%3A+null%2C+%22init_A_image_2%22%3A+null%2C+%22init_A_image_3%22%3A+null%7D%2C+%22photometricInterpretation%22%3A+%7B%22init_A_image_0%22%3A+%22BlackIsZero%22%7D%2C+%22metaCoordinationScopes%22%3A+%7B%22init_A_image_0%22%3A+%7B%22imageLayer%22%3A+%5B%22init_A_image_0%22%5D%7D%7D%2C+%22metaCoordinationScopesBy%22%3A+%7B%22init_A_image_0%22%3A+%7B%22imageLayer%22%3A+%7B%22fileUid%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%7D%2C+%22spatialLayerVisible%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%7D%2C+%22spatialLayerOpacity%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%7D%2C+%22imageChannel%22%3A+%7B%22init_A_image_0%22%3A+%5B%22init_A_image_0%22%2C+%22init_A_image_1%22%2C+%22init_A_image_2%22%2C+%22init_A_image_3%22%5D%7D%2C+%22photometricInterpretation%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%7D%7D%2C+%22imageChannel%22%3A+%7B%22spatialTargetC%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%2C+%22init_A_image_1%22%3A+%22init_A_image_1%22%2C+%22init_A_image_2%22%3A+%22init_A_image_2%22%2C+%22init_A_image_3%22%3A+%22init_A_image_3%22%7D%2C+%22spatialChannelColor%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%2C+%22init_A_image_1%22%3A+%22init_A_image_1%22%2C+%22init_A_image_2%22%3A+%22init_A_image_2%22%2C+%22init_A_image_3%22%3A+%22init_A_image_3%22%7D%2C+%22spatialChannelVisible%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%2C+%22init_A_image_1%22%3A+%22init_A_image_1%22%2C+%22init_A_image_2%22%3A+%22init_A_image_2%22%2C+%22init_A_image_3%22%3A+%22init_A_image_3%22%7D%2C+%22spatialChannelWindow%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%2C+%22init_A_image_1%22%3A+%22init_A_image_1%22%2C+%22init_A_image_2%22%3A+%22init_A_image_2%22%2C+%22init_A_image_3%22%3A+%22init_A_image_3%22%7D%7D%7D%7D%7D%2C+%22layout%22%3A+%5B%7B%22component%22%3A+%22spatialBeta%22%2C+%22coordinationS ...

# %%
sdata["table_transcriptomics_preprocessed"].obs.head()
# Out:
#                                          cell_ID                 fov_labels  \
# cells
# 1039_nucleus_segmentation_mask_efa3e768     1039  nucleus_segmentation_mask
# 1071_nucleus_segmentation_mask_efa3e768     1071  nucleus_segmentation_mask
# 1135_nucleus_segmentation_mask_efa3e768     1135  nucleus_segmentation_mask
# 1167_nucleus_segmentation_mask_efa3e768     1167  nucleus_segmentation_mask
# 1199_nucleus_segmentation_mask_efa3e768     1199  nucleus_segmentation_mask
#
#                                          n_genes_by_counts  \
# cells
# 1039_nucleus_segmentation_mask_efa3e768                168
# 1071_nucleus_segmentation_mask_efa3e768                312
# 1135_nucleus_segmentation_mask_efa3e768                220
# 1167_nucleus_segmentation_mask_efa3e768                190
# 1199_nucleus_segmentation_mask_efa3e768                106
#
#                                          log1p_n_genes_by_counts  \
# cells
# 1039_nucleus_segmentation_mask_efa3e768                 5.129899
# 1071_nucleus_segmentation_mask_efa3e768                 5.746203
# 1135_nucleus_segmentation_mask_efa3e768                 5.398163
# 1167_nucleus_segmentation_mask_efa3e768                 5.252273
# 1199_nucleus_segmentation_mask_efa3e768                 4.672829
#
#                                          total_counts  log1p_total_counts  \
# cells
# 1039_nucleus_segmentation_mask_efa3e768           218            5.389072
# 1071_nucleus_segmentation_mask_efa3e768           414            6.028279
# 1135_nucleus_segmentation_mask_efa3e768           305            5.723585
# 1167_nucleus_segmentation_mask_efa3e768           239            5.480639
# 1199_nucleus_segmentation_mask_efa3e768           118            4.779123
#
#                                          pct_counts_in_top_2_genes  \
# cells
# 1039_nucleus_segmentation_mask_efa3e768                   7.339450
# 1071_nucleus_segmentation_mask_efa3e768                   3.864734
# 1135_nucleus_segmentation_mask_efa3e768                   5.245902
# 1167_nucleus_segmentation_mask_efa3e768                   9.623431
# 1199_nucleus_segmentation_mask_efa3e768                   5.932203
#
#                                          pct_counts_in_top_5_genes  n_counts  \
# cells
# 1039_nucleus_segmentation_mask_efa3e768                  12.844037       218
# 1071_nucleus_segmentation_mask_efa3e768                   7.487923       414
# 1135_nucleus_segmentation_mask_efa3e768                  10.819672       305
# 1167_nucleus_segmentation_mask_efa3e768                  14.644351       239
# 1199_nucleus_segmentation_mask_efa3e768                  11.864407       118
#
#                                          shapeSize  shapeSize_microns leiden
# cells
# 1039_nucleus_segmentation_mask_efa3e768     2289.0         103.362663      4
# 1071_nucleus_segmentation_mask_efa3e768     1884.0          85.074379      5
# 1135_nucleus_segmentation_mask_efa3e768     2185.0          98.666412      4
# 1167_nucleus_segmentation_mask_efa3e768     2062.0          93.112190      6
# 1199_nucleus_segmentation_mask_efa3e768     1027.0          46.375469      2

# %%
vc = hpv.imgbased_transcriptomics_from_spatialdata(
    sdata_for_vitessce,
    base_dir=vitessce_base_dir,
    image_name="clahe",
    labels_name="nucleus_segmentation_mask",
    segmentation_filled=False,
    segmentation_stroke_width=0.025,
    segmentation_color="#00C2FF",  # segmentation color seems to be ignored if labels element is multiscale.
    channels=[0, 1, 2, 3],
    to_coordinate_system="global_micron",
)

url = vc.web_app()
display(HTML(f'<a href="{url}" target="_blank">Open in Vitessce</a>'))
# Out:
# 2026-06-18 11:49:55.042 | WARNING  | harpy_vitessce.vitessce_config._utils:_validate_camera:28 - zoom was provided without center. Vitessce ignores zoom unless center is also set.
# 2026-06-18 11:49:55.045 | INFO     | harpy_vitessce.vitessce_config._image:build_image_layer_config:158 - No palette provided and 4 channels selected; rendering with the default channel palette.
# <a href="http://vitessce.io/#?theme=light&url=data:,%7B%22version%22%3A+%221.0.18%22%2C+%22name%22%3A+%22Image-based+transcriptomics%22%2C+%22description%22%3A+%22Image-based+transcriptomics%22%2C+%22datasets%22%3A+%5B%7B%22uid%22%3A+%22A%22%2C+%22name%22%3A+%22Image-based+transcriptomics%22%2C+%22files%22%3A+%5B%7B%22fileType%22%3A+%22spatialdata.zarr%22%2C+%22url%22%3A+%22http%3A%2F%2Flocalhost%3A8004%2Fvar%2Ffolders%2Fsz%2Ft3tgg4fs4tz9btm0fbqg_tzc0000gn%2FT%2Fmacsima_1olhr4uw%2Fsdata.zarr%22%2C+%22options%22%3A+%7B%22image%22%3A+%7B%22path%22%3A+%22images%2Fclahe%22%2C+%22coordinateSystem%22%3A+%22global_micron%22%7D%2C+%22obsSegmentations%22%3A+%7B%22path%22%3A+%22labels%2Fnucleus_segmentation_mask%22%2C+%22coordinateSystem%22%3A+%22global_micron%22%7D%7D%2C+%22coordinationValues%22%3A+%7B%22obsType%22%3A+%22cell%22%2C+%22fileUid%22%3A+%22sdata_717d0f15-cbc9-4ad6-8bd0-9b82862ca331%22%7D%7D%5D%7D%5D%2C+%22coordinationSpace%22%3A+%7B%22dataset%22%3A+%7B%22A%22%3A+%22A%22%7D%2C+%22spatialZoom%22%3A+%7B%22A%22%3A+-4%7D%2C+%22spatialTargetX%22%3A+%7B%22A%22%3A+null%7D%2C+%22spatialTargetY%22%3A+%7B%22A%22%3A+null%7D%2C+%22imageLayer%22%3A+%7B%22init_A_image_0%22%3A+%22__dummy__%22%7D%2C+%22fileUid%22%3A+%7B%22init_A_image_0%22%3A+%22sdata_717d0f15-cbc9-4ad6-8bd0-9b82862ca331%22%2C+%22init_A_obsSegmentations_0%22%3A+%22sdata_717d0f15-cbc9-4ad6-8bd0-9b82862ca331%22%7D%2C+%22spatialLayerVisible%22%3A+%7B%22init_A_image_0%22%3A+true%7D%2C+%22spatialLayerOpacity%22%3A+%7B%22init_A_image_0%22%3A+1.0%7D%2C+%22imageChannel%22%3A+%7B%22init_A_image_0%22%3A+%22__dummy__%22%2C+%22init_A_image_1%22%3A+%22__dummy__%22%2C+%22init_A_image_2%22%3A+%22__dummy__%22%2C+%22init_A_image_3%22%3A+%22__dummy__%22%7D%2C+%22spatialTargetC%22%3A+%7B%22init_A_image_0%22%3A+0%2C+%22init_A_image_1%22%3A+1%2C+%22init_A_image_2%22%3A+2%2C+%22init_A_image_3%22%3A+3%2C+%22init_A_obsSegmentations_0%22%3A+0%7D%2C+%22spatialChannelColor%22%3A+%7B%22init_A_image_0%22%3A+%5B0%2C+255%2C+255%5D%2C+%22init_A_image_1%22%3A+%5B255%2C+0%2C+255%5D%2C+%22init_A_image_2%22%3A+%5B255%2C+165%2C+0%5D%2C+%22init_A_image_3%22%3A+%5B173%2C+255%2C+47%5D%2C+%22init_A_obsSegmentations_0%22%3A+%5B0%2C+194%2C+255%5D%7D%2C+%22spatialChannelVisible%22%3A+%7B%22init_A_image_0%22%3A+true%2C+%22init_A_image_1%22%3A+true%2C+%22init_A_image_2%22%3A+true%2C+%22init_A_image_3%22%3A+true%7D%2C+%22spatialChannelWindow%22%3A+%7B%22init_A_image_0%22%3A+null%2C+%22init_A_image_1%22%3A+null%2C+%22init_A_image_2%22%3A+null%2C+%22init_A_image_3%22%3A+null%7D%2C+%22photometricInterpretation%22%3A+%7B%22init_A_image_0%22%3A+%22BlackIsZero%22%7D%2C+%22metaCoordinationScopes%22%3A+%7B%22init_A_image_0%22%3A+%7B%22imageLayer%22%3A+%5B%22init_A_image_0%22%5D%7D%2C+%22init_A_obsSegmentations_0%22%3A+%7B%22segmentationLayer%22%3A+%5B%22init_A_obsSegmentations_0%22%5D%7D%7D%2C+%22metaCoordinationScopesBy%22%3A+%7B%22init_A_image_0%22%3A+%7B%22imageLayer%22%3A+%7B%22fileUid%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%7D%2C+%22spatialLayerVisible%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%7D%2C+%22spatialLayerOpacity%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%7D%2C+%22imageChannel%22%3A+%7B%22init_A_image_0%22%3A+%5B%22init_A_image_0%22%2C+%22init_A_image_1%22%2C+%22init_A_image_2%22%2C+%22init_A_image_3%22%5D%7D%2C+%22photometricInterpretation%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%7D%7D%2C+%22imageChannel%22%3A+%7B%22spatialTargetC%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%2C+%22init_A_image_1%22%3A+%22init_A_image_1%22%2C+%22init_A_image_2%22%3A+%22init_A_image_2%22%2C+%22init_A_image_3%22%3A+%22init_A_image_3%22%7D%2C+%22spatialChannelColor%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%2C+%22init_A_image_1%22%3A+%22init_A_image_1%22%2C+%22init_A_image_2%22%3A+%22init_A_image_2%22%2C+%22init_A_image_3%22%3A+%22init_A_image_3%22%7D%2C+%22spatialChannelVisible%22%3A+%7B%22init_A_image_0%22%3A+%22init_A_image_0%22%2C+%22init_A_image_1%22%3A+%22ini ...

# %%
[*sdata.tables]
# Out:
# ['table_global', 'table_transcriptomics', 'table_transcriptomics_preprocessed']

# %%
vc = hpv.imgbased_transcriptomics_from_spatialdata(
    sdata_for_vitessce,
    base_dir=vitessce_base_dir,
    image_name="clahe",
    labels_name="nucleus_segmentation_mask",
    table_name="table_transcriptomics_preprocessed",
    channels=[0, 1, 2, 3],
    cluster_key="leiden",
    embedding_key="X_umap",
    to_coordinate_system="global_micron",
)

url = vc.web_app()
display(HTML(f'<a href="{url}" target="_blank">Open in Vitessce</a>'))
# Out:
# 2026-06-10 10:50:40.078 | WARNING  | harpy_vitessce.vitessce_config._utils:_validate_camera:28 - zoom was provided without center. Vitessce ignores zoom unless center is also set.
# 2026-06-10 10:50:40.084 | INFO     | harpy_vitessce.vitessce_config._image:build_image_layer_config:158 - No palette provided and 4 channels selected; rendering with the default channel palette.
# <a href="http://vitessce.io/#?theme=light&url=data:,%7B%22version%22%3A+%221.0.18%22%2C+%22name%22%3A+%22Image-based+transcriptomics%22%2C+%22description%22%3A+%22Image-based+transcriptomics%22%2C+%22datasets%22%3A+%5B%7B%22uid%22%3A+%22A%22%2C+%22name%22%3A+%22Image-based+transcriptomics%22%2C+%22files%22%3A+%5B%7B%22fileType%22%3A+%22spatialdata.zarr%22%2C+%22url%22%3A+%22http%3A%2F%2Flocalhost%3A8042%2FA%2F0%2F5df30ac3-0421-4ecd-8165-b75f4e0471c1.sdata.zarr%22%2C+%22options%22%3A+%7B%22obsFeatureMatrix%22%3A+%7B%22path%22%3A+%22tables%2Ftable_transcriptomics_preprocessed
7D%2C+%22spatialChannelVisible%22%3A+%7B%22init_A_image_0%22%3A+true%2C+%22init_A_image_1%22%3A+true%2C+%22init_A_image_2%22%3A+true%2C+%22init_A_image_3%22%3A+true%7D%2C+%22spatialChannelWindow%22%3A+%7B%22init_A_image_0%22%3A+null%2C+%22init_A_image_1%22%3A+null%2C+%22init_A_image_2%22%3A+null%2C+%22init_A_image_3%22%3A+null%7D%2C+%22photometricInterpretation%22%3A+%7B%22init_A_image_0%22%3A+%22BlackIsZero%22%7D%2C+%22metaCoordinationScopes%22%3A+%7B%22init_A_image_0%22%3A+%7B%22imageLayer%22%3A+%5B%22init_A_image_0%22%5D%7D%2C+%22init_A_obsSegmentations_0%22%3A+%7B%22segmentationLayer%22%3A+%5B%22init_A_obsSegmentations_0%22%5D%7D%7D%2C+ ...

# %%
vc = hpv.imgbased_transcriptomics_from_spatialdata(
    sdata_for_vitessce,
    base_dir=vitessce_base_dir,
    image_name="clahe",
    labels_name="nucleus_segmentation_mask",
    table_name="table_transcriptomics_preprocessed",
    channels=[0, 1, 2, 3],
    cluster_key="leiden",
    visualize_feature_matrix=True,
    embedding_key="X_umap",
    to_coordinate_system="global_micron",
)

url = vc.web_app()
display(HTML(f'<a href="{url}" target="_blank">Open in Vitessce</a>'))
# Out:
# 2026-06-18 11:50:18.184 | WARNING  | harpy_vitessce.vitessce_config._utils:_validate_camera:28 - zoom was provided without center. Vitessce ignores zoom unless center is also set.
# 2026-06-18 11:50:18.188 | INFO     | harpy_vitessce.vitessce_config._image:build_image_layer_config:158 - No palette provided and 4 channels selected; rendering with the default channel palette.
# <a href="http://vitessce.io/#?theme=light&url=data:,%7B%22version%22%3A+%221.0.18%22%2C+%22name%22%3A+%22Image-based+transcriptomics%22%2C+%22description%22%3A+%22Image-based+transcriptomics%22%2C+%22datasets%22%3A+%5B%7B%22uid%22%3A+%22A%22%2C+%22name%22%3A+%22Image-based+transcriptomics%22%2C+%22files%22%3A+%5B%7B%22fileType%22%3A+%22spatialdata.zarr%22%2C+%22url%22%3A+%22http%3A%2F%2Flocalhost%3A8005%2Fvar%2Ffolders%2Fsz%2Ft3tgg4fs4tz9btm0fbqg_tzc0000gn%2FT%2Fmacsima_1olhr4uw%2Fsdata.zarr%22%2C+%22options%22%3A+%7B%22obsFeatureMatrix%22%3A+%7B%22path%22%3A+%22tables%2Ftable_transcriptomics_preprocessed%2FX%22%2C+%22region%22%3A+%22nucleus_segmentation_mask%22%7D%2C+%22obsSets%22%3A+%7B%22obsSets%22%3A+%5B%7B%22name%22%3A+%22Clusters%22%2C+%22path%22%3A+%22tables%2Ftable_transcriptomics_preprocessed%2Fobs%2Fleiden%22%7D%5D%2C+%22tablePath%22%3A+%22tables%2Ftable_transcriptomics_preprocessed%22%2C+%22region%22%3A+%22nucleus_segmentation_mask%22%7D%2C+%22image%22%3A+%7B%22path%22%3A+%22images%2Fclahe%22%2C+%22coordinateSystem%22%3A+%22global_micron%22%7D%2C+%22obsSegmentations%22%3A+%7B%22path%22%3A+%22labels%2Fnucleus_segmentation_mask%22%2C+%22tablePath%22%3A+%22tables%2Ftable_transcriptomics_preprocessed%22%2C+%22coordinateSystem%22%3A+%22global_micron%22%7D%2C+%22obsEmbedding%22%3A+%5B%7B%22path%22%3A+%22tables%2Ftable_transcriptomics_preprocessed%2Fobsm%2FX_umap%22%2C+%22dims%22%3A+%5B0%2C+1%5D%2C+%22embeddingType%22%3A+%22UMAP%22%7D%5D%7D%2C+%22coordinationValues%22%3A+%7B%22obsType%22%3A+%22cell%22%2C+%22fileUid%22%3A+%22sdata_1977149f-042b-48f6-bf45-9e207964f5fe%22%2C+%22featureType%22%3A+%22gene%22%2C+%22featureValueType%22%3A+%22value%22%7D%7D%5D%7D%5D%2C+%22coordinationSpace%22%3A+%7B%22dataset%22%3A+%7B%22A%22%3A+%22A%22%7D%2C+%22spatialZoom%22%3A+%7B%22A%22%3A+-4%7D%2C+%22spatialTargetX%22%3A+%7B%22A%22%3A+null%7D%2C+%22spatialTargetY%22%3A+%7B%22A%22%3A+null%7D%2C+%22embeddingType%22%3A+%7B%22A%22%3A+%22UMAP%22%7D%2C+%22obsType%22%3A+%7B%22A%22%3A+%22cell%22%2C+%22init_A_obsSegmentations_0%22%3A+%22cell%22%7D%2C+%22featureType%22%3A+%7B%22A%22%3A+%22gene%22%7D%2C+%22featureValueType%22%3A+%7B%22A%22%3A+%22value%22%7D%2C+%22obsColorEncoding%22%3A+%7B%22A%22%3A+%22cellSetSelection%22%7D%2C+%22featureSelection%22%3A+%7B%22A%22%3A+null%7D%2C+%22obsSetSelection%22%3A+%7B%22A%22%3A+null%7D%2C+%22obsSetColor%22%3A+%7B%22A%22%3A+null%7D%2C+%22obsHighlight%22%3A+%7B%22A%22%3A+null%7D%2C+%22imageLayer%22%3A+%7B%22init_A_image_0%22%3A+%22__dummy__%22%7D%2C+%22fileUid%22%3A+%7B%22init_A_image_0%22%3A+%22sdata_1977149f-042b-48f6-bf45-9e207964f5fe%22%2C+%22init_A_obsSegmentations_0%22%3A+%22sdata_1977149f-042b-48f6-bf45-9e207964f5fe%22%7D%2C+%22spatialLayerVisible%22%3A+%7B%22init_A_image_0%22%3A+true%7D%2C+%22spatialLayerOpacity%22%3A+%7B%22init_A_image_0%22%3A+1.0%7D%2C+%22imageChannel%22%3A+%7B%22init_A_image_0%22%3A+%22__dummy__%22%2C+%22init_A_image_1%22%3A+%22__dummy__%22%2C+%22init_A_image_2%22%3A+%22__dummy__%22%2C+%22init_A_image_3%22%3A+%22__dummy__%22%7D%2C+%22spatialTargetC%22%3A+%7B%22init_A_image_0%22%3A+0%2C+%22init_A_image_1%22%3A+1%2C+%22init_A_image_2%22%3A+2%2C+%22init_A_image_3%22%3A+3%2C+%22init_A_obsSegmentations_0%22%3A+0%7D%2C+%22spatialChannelColor%22%3A+%7B%22init_A_image_0%22%3A+%5B0%2C+255%2C+255%5D%2C+%22init_A_image_1%22%3A+%5B255%2C+0%2C+255%5D%2C+%22init_A_image_2%22%3A+%5B255%2C+165%2C+0%5D%2C+%22init_A_image_3%22%3A+%5B173%2C+255%2C+47%5D%7D%2C+%22spatialChannelVisible%22%3A+%7B%22init_A_image_0%22%3A+true%2C+%22init_A_image_1%22%3A+true%2C+%22init_A_image_2%22%3A+true%2C+%22init_A_image_3%22%3A+true%7D%2C+%22spatialChannelWindow%22%3A+%7B%22init_A_image_0%22%3A+null%2C+%22init_A_image_1%22%3A+null%2C+%22init_A_image_2%22%3A+null%2C+%22init_A_image_3%22%3A+null%7D%2C+%22photometricInterpretation%22%3A+%7B%22init_A_image_0%22%3A+%22BlackIsZero%22%7D%2C+%22metaCoordinationScopes%22%3A+%7B%22init_A_image_0%22%3A+%7B%22imageLayer%22%3A+%5B%22init_A_image_0%22%5D%7D%2C+%22init_A_obsSegmentations_0% ...
